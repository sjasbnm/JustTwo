# %%
#Decision Tree implementation

# %%
#list of functions

import numpy as np
from collections import Counter
from treenode import TreeNode


class DecisionTree():

    def __init__()

    def _entropy()
    
    def _class_probabilities()

    def _data_entropy()
    
    def _partition_entropy()
    
    def _split()
    
    def _select_features_to_use()
        
    def _find_best_split()

    def _find_label_probs()

    def _create_tree()
    
    def _predict_one_sample()

    def train()

    def predict_probability()
        
    def predict()  
        
    def _print_recursive()

    def print_tree()

    def _calculate_feature_importance()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Example 3D data
x, y, z = np.random.rand(3, 100)  # Replace with your embedding coordinates

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)
plt.show()

# %%
import plotly.express as px
import numpy as np

# Example 3D data
x, y, z = np.random.rand(3, 100)
labels = np.random.choice(['label1', 'label2', 'label3'], 100)

fig = px.scatter_3d(x=x, y=y, z=z, color=labels)
fig.show()
